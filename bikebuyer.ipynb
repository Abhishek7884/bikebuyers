# %%
import os
os.getcwd();

# %%
os.chdir("C:/Users/Dell/Desktop/data set")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Dell\\Desktop\\data set'

# %%
import pandas as pd
data2=pd.read_csv("bikebuyer1.csv")
data2
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0            NaN  Female          70000       2.0
# 5         4.0        Married     NaN         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0            NaN  Female              0       NaN
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single     NaN          60000       0.0
# 13    14902.0            NaN  Female          40000       0.0
# ...

# %%
data2.describe()
data2.columns
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Yearly Income', 'Children',
#        'Education', 'Occupation', 'Home Owner', 'Cars', 'Commute Distance',
#        'Region', 'Age', 'Bike Buyer'],
#       dtype='object')

# %%
data2.dtypes
# Out:
# ID                  float64
# Marital Status       object
# Gender               object
# Yearly Income         int64
# Children            float64
# Education            object
# Occupation           object
# Home Owner           object
# Cars                  int64
# Commute Distance    float64
# Region               object
# Age                   int64
# Bike Buyer           object
# dtype: object

# %%
data2.isnull().sum()
# Out:
# ID                   1
# Marital Status      16
# Gender              29
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
features = data2.iloc[:,:].values
features
# Out:
# array([[22711.0, 'Single', 'Male', ..., 'Europe', 33, 'Yes'],
#        [13555.0, 'Married', 'Female', ..., 'Europe', 37, 'Yes'],
#        [nan, 'Married', 'Male', ..., 'Europe', 55, 'No'],
#        ...,
#        [22823.0, 'Married', 'Female', ..., 'Europe', 53, 'No'],
#        [22825.0, 'Single', 'Female', ..., 'Europe', 54, 'No'],
#        [22826.0, 'Married', 'Male', ..., 'Europe', 54, 'No']],
#       dtype=object)

# %%
labels = data2.iloc[:,1].values
labels
# Out:
# array(['Single', 'Married', 'Married', ..., 'Married', 'Single',
#        'Married'], dtype=object)

# %%
data2.corr()
# Out:
#                         ID  Yearly Income  Children      Cars  \
# ID                1.000000      -0.006802  0.012046  0.068315
# Yearly Income    -0.006802       1.000000  0.474575  0.472089
# Children          0.012046       0.474575  1.000000  0.448379
# Cars              0.068315       0.472089  0.448379  1.000000
# Commute Distance  0.011511       0.009467  0.026377  0.018397
# Age               0.021135       0.195351 -0.000520  0.141093
#
#                   Commute Distance       Age
# ID                        0.011511  0.021135
# Yearly Income             0.009467  0.195351
# Children                  0.026377 -0.000520
# Cars                      0.018397  0.141093
# Commute Distance          1.000000 -0.026119
# Age                      -0.026119  1.000000

# %%
data2.cov()
# Out:
#                             ID  Yearly Income      Children          Cars  \
# ID                1.881329e+07  -9.459130e+05     83.508727    339.793815
# Yearly Income    -9.459130e+05   1.029155e+09  24380.349828  17367.818463
# Children          8.350873e+01   2.438035e+04      2.562919      0.823193
# Cars              3.397938e+02   1.736782e+04      0.823193      1.315109
# Commute Distance  1.458264e+02   8.889422e+02      0.123484      0.061749
# Age               1.092423e+03   7.468094e+04     -0.009929      1.928144
#
#                   Commute Distance           Age
# ID                      145.826442   1092.422656
# Yearly Income           888.942245  74680.941428
# Children                  0.123484     -0.009929
# Cars                      0.061749      1.928144
# Commute Distance          8.562711     -0.910780
# Age                      -0.910780    142.006631

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['Yearly Income'].hist(bins=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['Commute Distance'].hist(bins=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['Age'].hist(bins=10)

# %%
 import matplotlib.pyplot as plt
# %matplotlib inline
data2[ 'Cars'].hist(bins=10)

# %%
df1=pd.DataFrame(data2)
cols=['ID', 'Marital Status', 'Gender', 'Yearly Income', 'Children',
       'Education', 'Occupation', 'Home Owner', 'Cars', 'Commute Distance',
       'Region', 'Age', 'Bike Buyer']
df1[cols] = df1[cols].fillna(df1.mean().iloc[0])

# %%
df1.isnull().sum()
# Out:
# ID                  0
# Marital Status      0
# Gender              0
# Yearly Income       0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Bike Buyer          0
# dtype: int64

# %%
_=plt.scatter(df1['Age'],df1['Bike Buyer'],  color='black')
_=plt.title('Age vs Bike Buyer')
_=plt.xlabel('Age')
_=plt.ylabel('Bike Buyer')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
_=plt.scatter(df1['Children'],df1['Commute Distance'],  color='black')
_=plt.title('Children  vs Commute Distance')
_=plt.xlabel('Children')
_=plt.ylabel('Commute Distance')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
_=plt.scatter(df1['Age'],df1['Commute Distance'],  color='black')
_=plt.title('Age  vs Commute Distance')
_=plt.xlabel('Age')
_=plt.ylabel('Commute Distance')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
_=plt.scatter(df1['Age'],df1['Yearly Income'],  color='black')
_=plt.title('Age  vs Yearly Income')
_=plt.xlabel('Age')
_=plt.ylabel('Yearly Income')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
df1.boxplot(column='Commute Distance')

# %%
df1.boxplot(column='Cars')

# %%
df1.boxplot(column='Age')

# %%
df1.boxplot(column='Yearly Income')

# %%
df1.boxplot(column='Children')

# %%
import seaborn as sns
sns.pairplot(df1)

# %%
sns.distplot(df1['Age'])
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df1['Cars'])

# %%
sns.distplot(df1['Children'])

# %%
sns.distplot(df1['Yearly Income'])

# %%
sns.distplot(df1['ID'])

# %%
df1=df1.drop(['Marital Status' ],axis=1)
df1
# Out:
#                 ID   Gender  Yearly Income      Children            Education  \
# 0     22711.000000     Male          30000      0.000000      Partial College
# 1     13555.000000   Female          40000      0.000000      Graduate Degree
# 2     17744.435249     Male         160000      5.000000      Partial College
# 3         2.000000     Male         160000      0.000000      Graduate Degree
# 4     25410.000000   Female          70000      2.000000            Bachelors
# 5         4.000000  17744.4         120000      2.000000            Bachelors
# 6     15756.000000   Female          70000      0.000000          High School
# 7     11085.000000   Female          60000      0.000000          High School
# 8     17974.000000   Female              0  17744.435249            Bachelors
# 9     21008.000000   Female          20000      1.000000      Partial College
# 10    28985.000000     Male          50000      0.000000            Bachelors
# ...

# %%
df1=df1.drop(['Gender','Bike Buyer','Region','Education','Occupation','Home Owner'],axis=1)
df1
# Out:
#                 ID  Yearly Income      Children  Cars  Commute Distance  Age
# 0     22711.000000          30000      0.000000     1          1.000000   33
# 1     13555.000000          40000      0.000000     0          1.000000   37
# 2     17744.435249         160000      5.000000     3          2.000000   55
# 3         2.000000         160000      0.000000     2          5.000000   47
# 4     25410.000000          70000      2.000000     1          1.000000   38
# 5         4.000000         120000      2.000000     3          1.000000   40
# 6     15756.000000          70000      0.000000     2      17744.435249   49
# 7     11085.000000          60000      0.000000     2          1.000000   49
# 8     17974.000000              0  17744.435249     0         10.000000   38
# 9     21008.000000          20000      1.000000     0          1.000000   46
# 10    28985.000000          50000      0.000000     2          2.000000   64
# ...

# %%
x=df1.iloc[:,1]

y=df1.iloc[:,-1]

# %%
x_var=df1[['Cars']]
y_var=df1[ 'Age']
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    Age   R-squared:                       0.648
# Model:                            OLS   Adj. R-squared:                  0.648
# Method:                 Least Squares   F-statistic:                 1.286e+04
# Date:                Thu, 05 Nov 2020   Prob (F-statistic):               0.00
# Time:                        18:08:30   Log-Likelihood:                -33167.
# No. Observations:                6997   AIC:                         6.634e+04
# Df Residuals:                    6996   BIC:                         6.634e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Cars          19.1773      0.169    113.389      0.000      18.846      19.509
# ...

# %%
from sklearn import model_selection, neighbors
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=5)

# %%
features = x_train.values.reshape(-1,1)

# %%
labels = y_train.values.reshape(-1,1)

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.039718648567339754

# %%
x=df1.iloc[:,0:9]
y=df1.iloc[:,-1]

# %%
x
# Out:
#                 ID  Yearly Income      Children  Cars  Commute Distance  Age
# 0     22711.000000          30000      0.000000     1          1.000000   33
# 1     13555.000000          40000      0.000000     0          1.000000   37
# 2     17744.435249         160000      5.000000     3          2.000000   55
# 3         2.000000         160000      0.000000     2          5.000000   47
# 4     25410.000000          70000      2.000000     1          1.000000   38
# 5         4.000000         120000      2.000000     3          1.000000   40
# 6     15756.000000          70000      0.000000     2      17744.435249   49
# 7     11085.000000          60000      0.000000     2          1.000000   49
# 8     17974.000000              0  17744.435249     0         10.000000   38
# 9     21008.000000          20000      1.000000     0          1.000000   46
# 10    28985.000000          50000      0.000000     2          2.000000   64
# ...

# %%
y
# Out:
# 0       33
# 1       37
# 2       55
# 3       47
# 4       38
# 5       40
# 6       49
# 7       49
# 8       38
# 9       46
# 10      64
# 11      49
# 12      31
# 13      50
# 14      49
# 15      44
# 16      39
# 17      51
# 18      48
# 19      45
# 20      43
# 21      41
# 22      44
# 23      37
# 24      44
# 25      62
# 26      44
# 27      44
# 28      49
# 29      37
#         ..
# 6967    54
# 6968    55
# 6969    54
# 6970    54
# 6971    53
# 6972    53
# 6973    48
# 6974    49
# 6975    49
# 6976    49
# 6977    50
# 6978    51
# 6979    51
# 6980    51
# 6981    62
# 6982    62
# 6983    62
# 6984    61
# 6985    61
# 6986    61
# 6987    61
# 6988    60
# 6989    60
# 6990    60
# 6991    53
# 6992    52
# 6993    52
# 6994    53
# 6995    54
# 6996    54
# Name: Age, Length: 6997, dtype: int64

# %%
from sklearn import preprocessing
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
minmax.fit(x).transform(x)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# array([[7.70475673e-01, 1.76470588e-01, 0.00000000e+00, 2.50000000e-01,
#         0.00000000e+00, 1.12676056e-01],
#        [4.59829002e-01, 2.35294118e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.69014085e-01],
#        [6.01969032e-01, 9.41176471e-01, 2.81778480e-04, 7.50000000e-01,
#         5.63588722e-05, 4.22535211e-01],
#        ...,
#        [7.74275633e-01, 9.41176471e-01, 2.81778480e-04, 5.00000000e-01,
#         0.00000000e+00, 3.94366197e-01],
#        [7.74343489e-01, 7.05882353e-01, 2.81778480e-04, 7.50000000e-01,
#         0.00000000e+00, 4.08450704e-01],
#        [7.74377417e-01, 7.64705882e-01, 2.81778480e-04, 7.50000000e-01,
#         5.63588722e-05, 4.08450704e-01]])

# %%
x_var=df1[['ID','Yearly Income','Children','Cars','Commute Distance']]
y_var=df1[ 'Age']
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    Age   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                 1.304e+04
# Date:                Thu, 05 Nov 2020   Prob (F-statistic):               0.00
# Time:                        18:35:10   Log-Likelihood:                -28648.
# No. Observations:                6997   AIC:                         5.731e+04
# Df Residuals:                    6992   BIC:                         5.734e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
x_var=df1[['Age','Yearly Income','Children','Cars','Commute Distance']]
y_var=df1[ 'ID']
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     ID   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                 1.133e+04
# Date:                Thu, 05 Nov 2020   Prob (F-statistic):               0.00
# Time:                        18:36:40   Log-Likelihood:                -70863.
# No. Observations:                6997   AIC:                         1.417e+05
# Df Residuals:                    6992   BIC:                         1.418e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
#Splitting the dataset into Training set and Test set
from sklearn import model_selection, neighbors
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=5)

# %%
features = x_train.iloc[:,:].values

# %%
features
# Out:
# array([[1.1300e+04, 8.0000e+04, 4.0000e+00, 3.0000e+00, 1.0000e+00,
#         4.6000e+01],
#        [2.1632e+04, 5.0000e+04, 3.0000e+00, 3.0000e+00, 4.0000e+00,
#         4.1000e+01],
#        [1.2491e+04, 4.0000e+04, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         4.0000e+01],
#        ...,
#        [1.7119e+04, 4.0000e+04, 4.0000e+00, 1.0000e+00, 6.0000e+00,
#         3.1000e+01],
#        [1.3483e+04, 4.0000e+04, 0.0000e+00, 2.0000e+00, 2.0000e+00,
#         5.4000e+01],
#        [1.4799e+04, 2.0000e+04, 2.0000e+00, 0.0000e+00, 7.0000e+00,
#         4.1000e+01]])

# %%
labels = y_train.iloc[:].values

# %%
labels=labels

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 1.0

# %%
predictions = model.predict(X)

# %%
from sklearn.metrics import mean_squared_error, r2_score


print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [ 2.05784160e-19  5.54702011e-19 -7.34075815e-17 -6.57942091e-15
#  -4.98460798e-17  1.00000000e+00]
# Intercept: 2.842170943040401e-14
#
#
# The model performance
# --------------------------------------
# RMSE is 9.044798565181837e-14
# R2 score is 1.0

# %%
#Build a Logistic Regression Model
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
lr = LogisticRegression()
y=lr.fit(x_train, y_train)
#lr.fit(x_train,y_train)#dichomous or binary classification.
#lr_acc = cross_val_score(lr, x_train_std, y_train, cv=3, scoring='accuracy', n_jobs=-1)
#lr_proba = cross_val_predict(lr, x_train_std, y_train, cv=3, method='predict_proba')
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
decision_tree_model = DecisionTreeRegressor()
decision_tree_fit = decision_tree_model.fit(x_train, y_train)
#life_features_train, life_features_test, life_labels_train, life_labels_test
#x_train, x_test, y_train, y_test 
decision_tree_score = cross_val_score(decision_tree_fit, x_train, y_train, cv = 5)
print("mean cross validation score: %.2f"  % np.mean(decision_tree_score))
print("score without cv: %.2f" % decision_tree_fit.score(x_train, y_train))
print("R^2 score on the test data %.2f"% r2_score(y_test, decision_tree_fit.predict(x_test)))
# Out:
# mean cross validation score: 1.00
# score without cv: 1.00
# R^2 score on the test data 1.00

# %%
y_pred = decision_tree_model.predict(x_test)
#from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

#print("\nAccuracy score: %f" %(accuracy_score(y_test,y_pred) * 100))
#print("Recall score : %f" %(recall_score(y_test, y_pred) * 100))
#print("ROC score : %f\n" %(roc_auc_score(y_test, y_pred) * 100))
#print(confusion_matrix(y_test, y_pred)) #27 out of 114 have no cancer as told by the model.11 told that doctor predicted it has cancer but machine prididcted as it does not have cancer.
#1 data is there where doctor interpre

# %%
y_pred = decision_tree_model.predict(x_test)
#life_features_train, life_features_test, life_labels_train, life_labels_test
#x_train, x_test, y_train, y_test 
accuracy=decision_tree_model.score(x_test,y_test)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 1.0

# %%
y_pred
# Out:
# array([45., 30., 48., 46., 51., 44., 58., 50., 47., 64., 38., 37., 30.,
#        69., 51., 46., 46., 66., 29., 44., 60., 27., 46., 43., 42., 26.,
#        47., 42., 30., 44., 44., 43., 47., 57., 48., 58., 36., 30., 51.,
#        47., 27., 30., 34., 62., 36., 45., 55., 26., 60., 44., 63., 50.,
#        45., 38., 48., 41., 58., 56., 42., 45., 48., 48., 35., 35., 54.,
#        26., 38., 50., 56., 45., 48., 34., 41., 45., 41., 29., 58., 42.,
#        43., 48., 29., 52., 41., 50., 72., 54., 35., 53., 53., 52., 45.,
#        39., 42., 50., 55., 46., 48., 70., 69., 26., 43., 37., 39., 70.,
#        51., 37., 37., 54., 55., 43., 27., 67., 33., 39., 29., 48., 30.,
#        33., 49., 59., 50., 44., 59., 37., 38., 27., 48., 62., 39., 53.,
#        39., 58., 26., 50., 48., 67., 43., 32., 41., 39., 45., 32., 86.,
#        67., 62., 34., 59., 38., 48., 46., 29., 54., 41., 42., 33., 34.,
#        41., 27., 38., 40., 46., 56., 55., 46., 40., 30., 38., 35., 39.,
# ...

# %%
y_test
# Out:
# 4247    45
# 6174    30
# 141     48
# 9       46
# 1821    51
# 27      44
# 3819    58
# 5484    50
# 2902    47
# 1360    64
# 40      38
# 656     37
# 4884    30
# 2274    69
# 2223    51
# 1781    46
# 3720    46
# 5159    66
# 4279    29
# 5693    44
# 5046    60
# 3674    27
# 2529    46
# 1753    43
# 968     42
# 470     26
# 4671    47
# 5100    42
# 3759    30
# 4026    44
#         ..
# 246     33
# 5804    61
# 4675    44
# 4544    32
# 3155    30
# 6267    40
# 6765    50
# 4265    46
# 649     39
# 1714    40
# 5986    41
# 3215    45
# 1262    37
# 2945    33
# 3749    31
# 3870    45
# 2126    44
# 6600    31
# 42      67
# 4616    55
# 3994    70
# 6055    38
# 3134    53
# 3655    42
# 1422    37
# 3856    48
# 1590    48
# 4426    54
# 6239    57
# 2582    60
# Name: Age, Length: 700, dtype: int64

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

print("\nAccuracy score: %f" %(decision_tree_model.score(x_test,y_test) * 100))
# Out:
# Accuracy score: 100.000000

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_model = RandomForestRegressor()
random_forest_fit = random_forest_model.fit(x_train, y_train)
random_forest_score = cross_val_score(random_forest_fit, x_train, y_train, cv = 5)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
y_predict = random_forest_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

print("\nAccuracy score of random forest is: %f" %(random_forest_model.score(x_test,y_test) * 100))
# Out:
# Accuracy score of random forest is: 99.999720
